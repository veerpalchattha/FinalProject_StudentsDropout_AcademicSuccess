# %%
import pandas as pd

df = pd.read_csv("../data/cleaned/students_cleaned.csv")

# %%
df.columns
# Out:
# Index(['marital_status', 'application_mode', 'application_order', 'course',
#        'daytime_evening_attendance_t', 'previous_qualification',
#        'previous_qualification_grade', 'nacionality', 'mothers_qualification',
#        'fathers_qualification', 'mothers_occupation', 'fathers_occupation',
#        'admission_grade', 'displaced', 'educational_special_needs', 'debtor',
#        'tuition_fees_up_to_date', 'gender', 'scholarship_holder',
#        'age_at_enrollment', 'international',
#        'curricular units 1st sem (credited)',
#        'curricular_units_1st_sem_enrolled',
#        'curricular_units_1st_sem_evaluations',
#        'curricular_units_1st_sem_approved', 'curricular_units_1st_sem_grade',
#        'curricular_units_1st_sem_without_evaluations',
#        'curricular_units_2nd_sem_credited',
#        'curricular_units_2nd_sem_enrolled',
#        'curricular_units_2nd_sem_evaluations',
#        'curricular_units_2nd_sem_approved', 'curricular_units_2nd_sem_grade',
# ...

# %%
df.head(10)
# Out:
#    marital_status  application_mode  application_order  course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
# 5               2                39                  1    9991
# 6               1                 1                  1    9500
# 7               1                18                  4    9254
# 8               1                 1                  3    9238
# 9               1                 1                  1    9238
#
#    daytime_evening_attendance_t  previous_qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# ...

# %%
df.rename(columns={'curricular units 1st sem (credited)' : 'curricular_units_1st_sem_credited'}, inplace=True)

# %%
df.columns
# Out:
# Index(['marital_status', 'application_mode', 'application_order', 'course',
#        'daytime_evening_attendance_t', 'previous_qualification',
#        'previous_qualification_grade', 'nacionality', 'mothers_qualification',
#        'fathers_qualification', 'mothers_occupation', 'fathers_occupation',
#        'admission_grade', 'displaced', 'educational_special_needs', 'debtor',
#        'tuition_fees_up_to_date', 'gender', 'scholarship_holder',
#        'age_at_enrollment', 'international',
#        'curricular_units_1st_sem_credited',
#        'curricular_units_1st_sem_enrolled',
#        'curricular_units_1st_sem_evaluations',
#        'curricular_units_1st_sem_approved', 'curricular_units_1st_sem_grade',
#        'curricular_units_1st_sem_without_evaluations',
#        'curricular_units_2nd_sem_credited',
#        'curricular_units_2nd_sem_enrolled',
#        'curricular_units_2nd_sem_evaluations',
#        'curricular_units_2nd_sem_approved', 'curricular_units_2nd_sem_grade',
# ...

# %%
df.head(10)

# %%
df['age_at_enrollment']

# %%
students = df[[
    "age_at_enrollment",
    "displaced",
    "international"
    
]].copy()

students.to_csv("../data/cleaned/students.csv", index=False)

# %%
admission = df[[
    "application_mode",
    "daytime_evening_attendance_t",
    "application_order",
    "previous_qualification",
    "previous_qualification_grade",
    "admission_grade"
]].copy()

admission.to_csv("admission.csv", index=False)

# %%
education_special_needs = df[[
    "educational_special_needs"
]].copy()

education_special_needs.to_csv("../data/cleaned/education_special_needs.csv", index=False)

# %%
parents = df[[
    "mothers_qualification",
    "mothers_occupation",
    "fathers_qualification",
    "fathers_occupation"
]].copy()

parents.to_csv("../data/cleaned/parents.csv", index=False)

# %%
courses = df[[
    "course"
]].copy()

courses.to_csv("../data/cleaned/courses.csv", index=False)

# %%
nationality = df[[
    "nacionality"
]].copy()

nationality.to_csv("../data/cleaned/nationality.csv", index=False)

# %%
marital_status = df[[
    "marital_status"
]].copy()

marital_status.to_csv("../data/cleaned/marital_status.csv", index=False)

# %%
financial_status = df[[
    "debtor",
    "scholarship_holder",
    "tuition_fees_up_to_date"
]].copy()

financial_status.to_csv("../data/cleaned/financial_status.csv", index=False)

# %%
curricular_units = df[[
    "curricular_units_1st_sem_credited",
    "curricular_units_1st_sem_enrolled",
    "curricular_units_1st_sem_evaluations",
    "curricular_units_1st_sem_approved",
    "curricular_units_1st_sem_grade",
    "curricular_units_1st_sem_without_evaluations",
    "curricular_units_2nd_sem_credited",
    "curricular_units_2nd_sem_enrolled",
    "curricular_units_2nd_sem_evaluations",
    "curricular_units_2nd_sem_approved",
    "curricular_units_2nd_sem_grade",
    "curricular_units_2nd_sem_without_evaluations"
]].copy()

curricular_units.to_csv("../data/cleaned/curricular_units.csv", index=False)

# %%
countries = df[[
    "name"
]].copy()

countries.to_csv("../data/cleaned/countries.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 countries = df[[
#       2     "name"
#       3 ]].copy()
#       5 countries.to_csv("../data/cleaned/countries.csv", index=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
# ...

# %%
genders = df[[
    "gender"
]].copy()

genders.to_csv("../data/cleaned/genders.csv", index=False)

# %%
students_outcomes = df[[
    "target"
]].copy()

students_outcomes.to_csv("../data/cleaned/students_outcomes.csv", index=False)

# %%
economic_indicators = df[[
    "unemployment_rate",
    "inflation_rate",
    "gdp"
]].copy()

economic_indicators.to_csv("../data/cleaned/economic_indicators.csv", index=False)
